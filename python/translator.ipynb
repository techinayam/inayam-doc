# %%
# import os
# import json
# from googletrans import Translator  # Install using: pip install googletrans==4.0.0-rc1

# def translate_json_files(input_folder, output_folder, target_language):
#     """
#     Reads JSON files from the input folder, translates their content, 
#     and writes them to the output folder.
#     """
#     os.makedirs(output_folder, exist_ok=True)
    
#     translator = Translator()

#     def translate_nested_json(data):
#         if isinstance(data, dict):
#             return {key: translate_nested_json(value) for key, value in data.items()}
#         elif isinstance(data, list):
#             return [translate_nested_json(item) for item in data]
#         elif isinstance(data, str):
#             try:
#                 translated = translator.translate(data, dest=target_language)
#                 return translated.text
#             except Exception as e:
#                 print(f"Error translating '{data}': {e}")
#                 return data   
#         else:
#             return data  
        
#     def translate_text(text):
#         """
#         Translate a text string to the target language.
#         """
#         try:
#             # Translate the string to the target language
#             translated = translator.translate(text, dest=target_language)
#             return translated.text
#         except Exception as e:
#             print(f"Error translating '{text}': {e}")
#             return text  # Return the original text if translation fails


#     for filename in os.listdir(input_folder):
#         if filename.endswith(".md"):
#             print('0000 filename', filename)
#             input_path = os.path.join(input_folder, filename)
#             output_path = os.path.join(output_folder, filename)

#             with open(input_path, 'r', encoding='utf-8') as f:
#                 data = f.read()

                
#             print('1111 data', data)


#             translated_data = translate_text(data)


#             print('2222 translated_data', translated_data)

#             with open(output_path, 'w', encoding='utf-8') as f:
#                     f.write(translated_data)
            
#             print(f"Translated and saved: {output_path}")

# # Example usage
# input_folder = "/Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/en"
# output_folder = "/Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ta"
# target_language = "ta" 

# translate_json_files(input_folder, output_folder, target_language)

#OLD

# %%
import os
import json
from googletrans import Translator 
from concurrent.futures import ThreadPoolExecutor

def translate_json_files(input_folder, output_folder, target_language):
    """
    Reads JSON files from the input folder, translates their content, 
    and writes them to the output folder using parallel processing.
    """
    os.makedirs(output_folder, exist_ok=True)
    
    translator = Translator()

    def translate_text(text):
        """
        Translate a text string to the target language.
        """
        try:
            translated = translator.translate(text, dest=target_language)
            return translated.text
        except Exception as e:
            print(f"Error translating '{text}': {e}")

    def translate_file(filename):
        """
        Handles the translation of a single file.
        """
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)

        with open(input_path, 'r', encoding='utf-8') as f:
            data = f.read()

        print(f"Translating {filename}")

        translated_data = translate_text(data)

        with open(output_path, 'w', encoding='utf-8') as f:
            f.write(translated_data)

        print(f"Translated and saved: {output_path}")

    files_to_translate = [filename for filename in os.listdir(input_folder) if filename.endswith(".md")]
    
    with ThreadPoolExecutor() as executor:
        executor.map(translate_file, files_to_translate)

input_folder = "/Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/en"
output_folder = "/Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja"
target_language = "ja" 

translate_json_files(input_folder, output_folder, target_language)
# Out:
# Translating social-media-post.md
# Translating business-plan-generator.md
# Translating definition.md
# Translating social-media-post-ideas.md
# Translating paragraph-writer.md
# Translating blog-rewriter.md
# Translating domain-name.md
# Translating google-ad-title.md
# Translating call-to-action.md
# Translating song-writer.md
# Translating username.md
# Translating customer-service-response.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/paragraph-writer.mdTranslated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/google-ad-title.md
#
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/social-media-post-ideas.md
# Translating quiz-generator.md
# Translating youtube-tag.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/business-plan-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/social-media-post.md
# Translating topic-example-generator.md
# Translating homepage-headline.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/call-to-action.md
# Translating linkedin-ad-title.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/song-writer.md
# Translating bullet-point-summary.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/username.md
# Translating tiktok-hook.md
# Translating sentence-rewriter.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/blog-rewriter.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/definition.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/domain-name.md
# Translating ai-writing-generator.md
# Translating birthday-greeting-generator.md
# Translating seo-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/customer-service-response.md
# Translating linkedin-post.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/seo-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/birthday-greeting-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/ai-writing-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/youtube-tag.md
# Translating about-us.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/linkedin-ad-title.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/topic-example-generator.md
# Translating email-rewriter.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/homepage-headline.md
# Translating product-benefits.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/bullet-point-summary.md
# Translating ai-movie-recommendations.md
# Translating product-review.md
# Translating youtube-seo-title.md
# Translating twitter-hashtag.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/tiktok-hook.md
# Translating baby-girl-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/sentence-rewriter.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/quiz-generator.md
# Translating app-name.md
# Translating youtube-description.md
# Translating seo-keywords-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/linkedin-post.md
# Translating instagram-reel-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/about-us.mdTranslated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/instagram-reel-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/baby-girl-name.md
#
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/email-rewriter.md
# Translating wish-generator.md
# Translating poem-writer.md
# Translating email-response.md
# Translating email-follow-up.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/product-benefits.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/youtube-seo-title.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/ai-movie-recommendations.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/youtube-description.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/app-name.md
# Translating email-subject.md
# Translating question-answer-generator.md
# Translating facebook-hashtag.md
# Translating tiktok-hashtag.md
# Translating sales-copy-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/product-review.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/twitter-hashtag.md
# Translating article-rewriter.md
# Translating tiktok-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/seo-keywords-generator.md
# Translating pros-and-cons.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/tiktok-hashtag.mdTranslated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/question-answer-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/poem-writer.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/sales-copy-generator.md
#
# Translating twitter-bio.md
# Translating thank-you-note-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/wish-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/tiktok-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/pros-and-cons.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/email-response.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/email-follow-up.md
# Translating instagram-ad-copy.md
# Translating about-me.md
# Translating blog-post-hook.md
# Translating youtube-channel-name.md
# Translating youtube-hashtag.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/email-subject.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/article-rewriter.md
# Translating resume-hook.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/facebook-hashtag.md
# Translating instagram-hashtag.md
# Translating instagram-caption.md
# Translating youtube-intro.md
# Translating slogan-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/thank-you-note-generator.mdTranslated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/youtube-channel-name.md
#
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/about-me.md
# Translating email-newsletter.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/twitter-bio.md
# Translating blog-name.md
# Translating facebook-ad-hook.md
# Translating play-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/instagram-ad-copy.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/resume-hook.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/instagram-hashtag.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/slogan-generator.md
# Translating blog-post-title.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/instagram-caption.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/youtube-hashtag.md
# Translating linkedin-ad-description.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/youtube-intro.md
# Translating tiktok-ad-script.md
# Translating facebook-ad-copy.md
# Translating email-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/blog-post-hook.md
# Translating baby-boy-name.md
# Translating twitter-tweet.md
# Translating linkedin-cold-reachout.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/play-name.md
# Translating instagram-reel-ad-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/facebook-ad-hook.md
# Translating sentence-expander.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/email-newsletter.md
# Translating youtube-hook.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/baby-boy-name.mdTranslated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/linkedin-ad-description.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/facebook-ad-copy.md
#
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/linkedin-cold-reachout.md
# Translating content-rewriter.md
# Translating bullet-point-answer.md
# Translating facebook-post.md
# Translating job-skills-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/tiktok-ad-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/email-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/twitter-tweet.md
# Translating book-name.md
# Translating content-ideas.md
# Translating project-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/blog-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/blog-post-title.md
# Translating blog-post-outline.md
# Translating youtube-shorts-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/bullet-point-answer.md
# Translating blog-post-ideas.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/instagram-reel-ad-script.md
# Translating instagram-ad-caption.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/sentence-expander.md
# Translating question-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/youtube-hook.md
# Translating linkedin-story-post.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/job-skills-generator.mdTranslated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/content-rewriter.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/facebook-post.md
#
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/book-name.md
# Translating faq-generator.md
# Translating seo-title-generator.md
# Translating youtube-video-ideas.md
# Translating short-video-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/youtube-shorts-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/content-ideas.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/project-name.md
# Translating fact-generator.md
# Translating linkedin-hashtag.md
# Translating ai-hashtag-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/blog-post-outline.md
# Translating job-description.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/linkedin-story-post.mdTranslated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/blog-post-ideas.md
#
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/instagram-ad-caption.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/question-generator.md
# Translating seo-description-generator.md
# Translating cafe-name.md
# Translating youtube-video-outline.md
# Translating twitter-thread.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/seo-title-generator.mdTranslated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/youtube-video-ideas.md
#
# Translating linkedin-post-hook.md
# Translating business-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/fact-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/ai-hashtag-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/faq-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/short-video-script.md
# Translating google-ad-description.md
# Translating blog-paragraph-writer.md
# Translating product-features.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/linkedin-hashtag.mdTranslated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/cafe-name.md
#
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/job-description.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/youtube-video-outline.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/seo-description-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/twitter-thread.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/business-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/product-features.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/google-ad-description.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/linkedin-post-hook.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ru/blog-paragraph-writer.md
