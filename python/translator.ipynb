# %%
# import os
# import json
# from googletrans import Translator  # Install using: pip install googletrans==4.0.0-rc1

# def translate_json_files(input_folder, output_folder, target_language):
#     """
#     Reads JSON files from the input folder, translates their content, 
#     and writes them to the output folder.
#     """
#     os.makedirs(output_folder, exist_ok=True)
    
#     translator = Translator()

#     def translate_nested_json(data):
#         if isinstance(data, dict):
#             return {key: translate_nested_json(value) for key, value in data.items()}
#         elif isinstance(data, list):
#             return [translate_nested_json(item) for item in data]
#         elif isinstance(data, str):
#             try:
#                 translated = translator.translate(data, dest=target_language)
#                 return translated.text
#             except Exception as e:
#                 print(f"Error translating '{data}': {e}")
#                 return data   
#         else:
#             return data  
        
#     def translate_text(text):
#         """
#         Translate a text string to the target language.
#         """
#         try:
#             # Translate the string to the target language
#             translated = translator.translate(text, dest=target_language)
#             return translated.text
#         except Exception as e:
#             print(f"Error translating '{text}': {e}")
#             return text  # Return the original text if translation fails


#     for filename in os.listdir(input_folder):
#         if filename.endswith(".md"):
#             print('0000 filename', filename)
#             input_path = os.path.join(input_folder, filename)
#             output_path = os.path.join(output_folder, filename)

#             with open(input_path, 'r', encoding='utf-8') as f:
#                 data = f.read()

                
#             print('1111 data', data)


#             translated_data = translate_text(data)


#             print('2222 translated_data', translated_data)

#             with open(output_path, 'w', encoding='utf-8') as f:
#                     f.write(translated_data)
            
#             print(f"Translated and saved: {output_path}")

# # Example usage
# input_folder = "/Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/en"
# output_folder = "/Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ta"
# target_language = "ta" 

# translate_json_files(input_folder, output_folder, target_language)

#OLD

# %%
import os
import json
from googletrans import Translator 
from concurrent.futures import ThreadPoolExecutor

def translate_json_files(input_folder, output_folder, target_language):
    """
    Reads JSON files from the input folder, translates their content, 
    and writes them to the output folder using parallel processing.
    """
    os.makedirs(output_folder, exist_ok=True)
    
    translator = Translator()

    def translate_text(text):
        """
        Translate a text string to the target language.
        """
        try:
            translated = translator.translate(text, dest=target_language)
            return translated.text
        except Exception as e:
            print(f"Error translating '{text}': {e}")

    def translate_file(filename):
        """
        Handles the translation of a single file.
        """
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)

        with open(input_path, 'r', encoding='utf-8') as f:
            data = f.read()

        print(f"Translating {filename}")

        translated_data = translate_text(data)

        with open(output_path, 'w', encoding='utf-8') as f:
            f.write(translated_data)

        print(f"Translated and saved: {output_path}")

    files_to_translate = [filename for filename in os.listdir(input_folder) if filename.endswith(".md")]
    
    with ThreadPoolExecutor() as executor:
        executor.map(translate_file, files_to_translate)

input_folder = "/Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/en"
output_folder = "/Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja"
target_language = "ja" 

translate_json_files(input_folder, output_folder, target_language)
# Out:
# Translating definition.md
# Translating social-media-post.md
# Translating paragraph-writer.md
# Translating blog-rewriter.md
# Translating domain-name.md
# Translating business-plan-generator.md
# Translating social-media-post-ideas.md
# Translating google-ad-title.md
# Translating song-writer.md
# Translating call-to-action.md
# Translating customer-service-response.md
# Translating username.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/social-media-post.mdTranslated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/domain-name.md
#
# Translating quiz-generator.md
# Translating youtube-tag.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/definition.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/social-media-post-ideas.md
# Translating topic-example-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/google-ad-title.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/blog-rewriter.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/call-to-action.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/song-writer.md
# Translating homepage-headline.md
# Translating sentence-rewriter.md
# Translating tiktok-hook.md
# Translating linkedin-ad-title.md
# Translating bullet-point-summary.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/paragraph-writer.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/business-plan-generator.md
# Translating birthday-greeting-generator.md
# Translating ai-writing-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/customer-service-response.md
# Translating seo-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/username.md
# Translating linkedin-post.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/linkedin-ad-title.mdTranslated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/homepage-headline.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/quiz-generator.md
#
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/sentence-rewriter.md
# Translating about-us.md
# Translating email-rewriter.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/linkedin-post.md
# Translating product-benefits.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/youtube-tag.md
# Translating twitter-hashtag.md
# Translating youtube-seo-title.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/birthday-greeting-generator.md
# Translating ai-movie-recommendations.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/seo-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/ai-writing-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/bullet-point-summary.md
# Translating product-review.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/topic-example-generator.md
# Translating app-name.md
# Translating youtube-description.md
# Translating baby-girl-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/tiktok-hook.md
# Translating seo-keywords-generator.md
# Translating instagram-reel-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/product-review.mdTranslated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/email-rewriter.md
#
# Translating poem-writer.md
# Translating wish-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/product-benefits.md
# Translating email-follow-up.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/ai-movie-recommendations.md
# Translating email-response.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/app-name.mdTranslated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/about-us.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/youtube-seo-title.md
#
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/seo-keywords-generator.md
# Translating question-answer-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/poem-writer.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/wish-generator.md
# Translating sales-copy-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/youtube-description.md
# Translating email-subject.md
# Translating facebook-hashtag.md
# Translating article-rewriter.md
# Translating tiktok-script.md
# Translating tiktok-hashtag.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/instagram-reel-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/twitter-hashtag.md
# Translating pros-and-cons.md
# Translating twitter-bio.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/email-response.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/baby-girl-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/email-follow-up.md
# Translating thank-you-note-generator.md
# Translating about-me.md
# Translating instagram-ad-copy.md
# Error translating '### Inayam AI Question & Answer Generator
#
# #### Introduction
# Welcome to the **Inayam AI Question & Answer Generator**, your go-to tool for creating insightful questions and answers across various subjects. Whether you're an educator looking to enhance your teaching materials, a student seeking to deepen your understanding, or simply someone eager to learn, our AI-powered tool is designed to educate and inform. With just a few clicks, you can generate tailored Q&A content that enriches your knowledge and learning experience.
#
# #### Usage Guide
# Using the Inayam AI Question & Answer Generator is simple and intuitive. Follow these steps to get started:
#
# 1. **Select a Topic**: Begin by entering the subject you want to explore in the designated input field. This could be anything from science, history, and mathematics to literature or technology.
#
# 2. **Generate Questions and Answers**: Once you’ve selected your topic, click the "Generate" button. Our AI will process your request and provide a set of relevant questions along with comprehensive answers.
#
# 3. **Review and Utilize**: Take a moment to review the generated content. You can use these questions and answers for study sessions, quizzes, or even as discussion starters in educational settings.
#
# #### Best Practices for Optimal Usage
# To make the most out of the Inayam AI Question & Answer Generator, consider these best practices:
#
# - **Be Specific**: When entering your topic, try to be as specific as possible. For instance, instead of just "science," you could specify "biology" or "physics" to get more targeted questions and answers.
#
# - **Explore Multiple Topics**: Don’t hesitate to experiment with different subjects. This will not only broaden your knowledge but also provide diverse perspectives on various themes.
#
# - **Use as a Learning Tool**: Incorporate the generated Q&A into your study routine. Quiz yourself or engage with peers using the questions to reinforce your learning.
#
# - **Feedback Loop**: If you find certain questions particularly useful or if you have suggestions for improvement, consider providing feedback to enhance the tool's capabilities.
#
# - **Stay Curious**: The more you use the tool, the more you’ll discover. Keep exploring new subjects and topics to continuously expand your knowledge base.
#
# #### Call to Action
# Ready to enhance your learning experience? **Start using the Inayam AI Question & Answer Generator now** and unlock a world of knowledge at your fingertips!
#
# ---
#
# ### FAQs
#
# **1. What subjects can I generate questions and answers for?**
# You can generate Q&A content for a wide range of subjects, including but not limited to science, history, mathematics, literature, and technology.
#
# **2. How accurate are the generated questions and answers?**
# The Inayam AI Question & Answer Generator utilizes advanced AI algorithms to provide accurate and relevant content. However, we recommend reviewing the information for context and accuracy.
#
# **3. Can I use the generated content for educational purposes?**
# Absolutely! The generated questions and answers are perfect for educational settings, study sessions, quizzes, and more.
#
# **4. Is there a limit to how many questions I can generate?**
# Currently, there is no limit to the number of questions you can generate. Feel free to explore as many topics as you like!
#
# **5. How can I provide feedback on the tool?**
# We welcome your feedback! You can reach out through our contact page to share your thoughts or suggestions for improving the Inayam AI Question & Answer Generator.
#
# ---
#
# With the Inayam AI Question & Answer Generator, you can effortlessly create engaging Q&A content that not only educates but also informs. Dive into the world of knowledge today!': <ConnectionTerminated error_code:ErrorCodes.COMPRESSION_ERROR, last_stream_id:91, additional_data:687061636b5f696e76616c69645f696e646578>
# Translating blog-post-hook.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/blog-post-hook.md
# Translating resume-hook.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/resume-hook.md
# Translating youtube-hashtag.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/youtube-hashtag.md
# Translating youtube-channel-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/youtube-channel-name.md
# Translating instagram-hashtag.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/instagram-hashtag.md
# Translating instagram-caption.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/instagram-caption.md
# Translating youtube-intro.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/youtube-intro.md
# Translating slogan-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/slogan-generator.md
# Translating email-newsletter.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/email-newsletter.md
# Translating blog-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/blog-name.md
# Translating facebook-ad-hook.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/facebook-ad-hook.md
# Translating play-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/play-name.md
# Translating facebook-ad-copy.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/facebook-ad-copy.md
# Translating tiktok-ad-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/tiktok-ad-script.md
# Translating blog-post-title.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/blog-post-title.md
# Translating linkedin-ad-description.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/linkedin-ad-description.md
# Translating email-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/email-generator.md
# Translating baby-boy-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/baby-boy-name.md
# Translating twitter-tweet.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/twitter-tweet.md
# Translating linkedin-cold-reachout.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/linkedin-cold-reachout.md
# Translating instagram-reel-ad-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/instagram-reel-ad-script.md
# Translating sentence-expander.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/sentence-expander.md
# Translating youtube-hook.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/youtube-hook.md
# Translating facebook-post.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/facebook-post.md
# Translating content-rewriter.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/content-rewriter.md
# Translating job-skills-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/job-skills-generator.md
# Translating bullet-point-answer.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/bullet-point-answer.md
# Translating book-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/book-name.md
# Translating content-ideas.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/content-ideas.md
# Translating project-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/project-name.md
# Translating blog-post-outline.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/blog-post-outline.md
# Translating youtube-shorts-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/youtube-shorts-script.md
# Translating blog-post-ideas.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/blog-post-ideas.md
# Translating instagram-ad-caption.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/instagram-ad-caption.md
# Translating question-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/question-generator.md
# Translating linkedin-story-post.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/linkedin-story-post.md
# Translating faq-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/faq-generator.md
# Translating youtube-video-ideas.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/youtube-video-ideas.md
# Translating seo-title-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/seo-title-generator.md
# Translating short-video-script.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/short-video-script.md
# Translating fact-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/fact-generator.md
# Translating linkedin-hashtag.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/linkedin-hashtag.md
# Translating ai-hashtag-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/ai-hashtag-generator.md
# Translating job-description.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/job-description.md
# Translating seo-description-generator.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/seo-description-generator.md
# Translating cafe-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/cafe-name.md
# Translating youtube-video-outline.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/youtube-video-outline.md
# Translating twitter-thread.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/twitter-thread.md
# Translating linkedin-post-hook.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/linkedin-post-hook.md
# Translating business-name.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/business-name.md
# Translating product-features.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/product-features.md
# Translating google-ad-description.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/google-ad-description.md
# Translating blog-paragraph-writer.md
# Translated and saved: /Users/rakesh.c/rakesh/my/am/inayam/inayam-doc/ai/ja/blog-paragraph-writer.md
